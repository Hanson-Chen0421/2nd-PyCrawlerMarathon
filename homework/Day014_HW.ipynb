# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 進入台灣銀行牌告匯率網頁，查看當日匯率資料
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url)
resp.encoding = 'utf-8'
# print(resp.text)  # 如有需要，列印出網頁原始碼

html = BeautifulSoup(resp.text, "lxml")
rate_table = html.find(name='table', attrs={'title':'牌告匯率'}).find(name='tbody').find_all(name='tr')

# 查詢美金(也就是匯率表的第一個元素)對台幣的匯率
currency = rate_table[0].find(name='div', attrs={'class':'visible-phone print_hide'})
print(currency.get_text().replace(" ", ""))  # 去掉空白

buy_rate = rate_table[0].find(name='td', attrs={'data-table':'本行現金買入'})
sell_rate = rate_table[0].find(name='td', attrs={'data-table':'本行現金賣出'})
print("即時現金買入: %s, 即時現金賣出: %s" % (buy_rate.get_text(), sell_rate.get_text()))
# Out:
# 美金(USD)
#
# 即時現金買入: 29.68, 即時現金賣出: 30.35

# %%
# 進入台灣銀行牌告匯率網頁，查看當日匯率資料
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
resp = requests.get(url)
resp.encoding = 'utf-8'
# print(resp.text)  # 如有需要，列印出網頁原始碼

html = BeautifulSoup(resp.text, "lxml")
rate_table = html.find(name='table', attrs={'title':'牌告匯率'}).find(name='tbody').find_all(name='tr')

#for i in rate_table:
    # 查詢美金(也就是匯率表的第一個元素)對台幣的匯率
    currency = rate_table[3].find(name='div', attrs={'class':'visible-phone print_hide'})
    print(currency.get_text().replace(" ", ""))  # 去掉空白

    buy_rate = rate_table[3].find(name='td', attrs={'data-table':'本行現金買入'})
    sell_rate = rate_table[3].find(name='td', attrs={'data-table':'本行現金賣出'})
    print("即時現金買入: %s, 即時現金賣出: %s" % (buy_rate.get_text(), sell_rate.get_text()))
# Out:
#   File "<ipython-input-8-6516ca0fecbd>", line 12
#     currency = rate_table[3].find(name='div', attrs={'class':'visible-phone print_hide'})
#     ^
# IndentationError: unexpected indent

# %%
print(rate_table)
# Out:
# [<tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-america-div">
# <img alt="幣別國旗" class="sp-img sp-america-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 美金 (USD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 美金 (USD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">29.68</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">30.35</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">30.03</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">30.13</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/USD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/USD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">29.68</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">30.35</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">30.03</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">30.13</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-hong-kong-div">
# <img alt="幣別國旗" class="sp-img sp-hong-kong-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 港幣 (HKD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 港幣 (HKD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">3.716</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">3.92</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">3.842</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">3.902</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/HKD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/HKD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">3.716</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">3.92</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">3.842</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">3.902</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-england-div">
# <img alt="幣別國旗" class="sp-img sp-england-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 英鎊 (GBP)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 英鎊 (GBP)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">38.47</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">40.59</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">39.47</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">39.89</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/GBP">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/GBP" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">38.47</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">40.59</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">39.47</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">39.89</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-australia-div">
# <img alt="幣別國旗" class="sp-img sp-australia-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 澳幣 (AUD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 澳幣 (AUD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">19.32</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">20.1</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">19.59</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">19.82</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/AUD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/AUD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">19.32</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">20.1</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">19.59</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">19.82</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-canada-div">
# <img alt="幣別國旗" class="sp-img sp-canada-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 加拿大幣 (CAD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 加拿大幣 (CAD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">21.55</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">22.46</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">21.94</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">22.16</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/CAD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/CAD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">21.55</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">22.46</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">21.94</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">22.16</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-singapore-div">
# <img alt="幣別國旗" class="sp-img sp-singapore-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 新加坡幣 (SGD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 新加坡幣 (SGD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">21.15</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">22.06</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">21.64</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">21.82</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/SGD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/SGD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">21.15</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">22.06</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">21.64</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">21.82</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-swiss-div">
# <img alt="幣別國旗" class="sp-img sp-swiss-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 瑞士法郎 (CHF)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 瑞士法郎 (CHF)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">31.67</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">32.87</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">32.33</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">32.62</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/CHF">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/CHF" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">31.67</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">32.87</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">32.33</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">32.62</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-japan-div">
# <img alt="幣別國旗" class="sp-img sp-japan-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 日圓 (JPY)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 日圓 (JPY)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.285</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">0.2978</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">0.2923</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">0.2963</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/JPY">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/JPY" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.285</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">0.2978</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">0.2923</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">0.2963</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-south-africa-div">
# <img alt="幣別國旗" class="sp-img sp-south-africa-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 南非幣 (ZAR)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 南非幣 (ZAR)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">-</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">1.817</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">1.897</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/ZAR">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/ZAR" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">1.817</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">1.897</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-sweden-div">
# <img alt="幣別國旗" class="sp-img sp-sweden-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 瑞典幣 (SEK)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 瑞典幣 (SEK)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">2.81</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">3.33</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">3.15</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">3.25</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/SEK">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/SEK" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">2.81</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">3.33</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">3.15</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">3.25</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-new-zealand-div">
# <img alt="幣別國旗" class="sp-img sp-new-zealand-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 紐元 (NZD)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 紐元 (NZD)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">18.39</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">19.24</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">18.77</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">18.97</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/NZD">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/NZD" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">18.39</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">19.24</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">18.77</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">18.97</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-thailand-div">
# <img alt="幣別國旗" class="sp-img sp-thailand-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 泰幣 (THB)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 泰幣 (THB)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.8257</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">1.0157</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">0.9381</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">0.9781</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/THB">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/THB" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.8257</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">1.0157</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">0.9381</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">0.9781</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-philippine-div">
# <img alt="幣別國旗" class="sp-img sp-philippine-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 菲國比索 (PHP)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 菲國比索 (PHP)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.5211</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">0.6541</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">-</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/PHP">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/PHP" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.5211</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">0.6541</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">-</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-indonesia-div">
# <img alt="幣別國旗" class="sp-img sp-indonesia-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 印尼幣 (IDR)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 印尼幣 (IDR)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.00173</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">0.00243</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">-</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/IDR">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/IDR" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.00173</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">0.00243</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">-</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-euro-div">
# <img alt="幣別國旗" class="sp-img sp-euro-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 歐元 (EUR)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 歐元 (EUR)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">33.58</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">34.92</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">34.2</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">34.6</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/EUR">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/EUR" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">33.58</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">34.92</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">34.2</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">34.6</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-korea-div">
# <img alt="幣別國旗" class="sp-img sp-korea-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 韓元 (KRW)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 韓元 (KRW)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.02329</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">0.02719</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">-</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/KRW">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/KRW" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.02329</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">0.02719</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">-</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-vietnam-div">
# <img alt="幣別國旗" class="sp-img sp-vietnam-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 越南盾 (VND)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 越南盾 (VND)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">0.00092</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">0.00142</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">-</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/VND">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/VND" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">0.00092</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">0.00142</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">-</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-malaysia-div">
# <img alt="幣別國旗" class="sp-img sp-malaysia-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 馬來幣 (MYR)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 馬來幣 (MYR)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">6.034</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">7.659</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">-</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">-</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/MYR">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/MYR" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">6.034</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">7.659</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">-</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">-</td>
# </tr>, <tr>
# <td class="currency phone-small-font" data-table="幣別">
# <div>
# <div class="sp-div sp-china-div">
# <img alt="幣別國旗" class="sp-img sp-china-img" src="/Content/images/sprite_lateral.png" title="幣別國旗"/>
# </div>
# <br class="visible-phone print_hide"/>
# <div class="visible-phone print_hide">
#                                 人民幣 (CNY)
#                             </div>
# <div class="hidden-phone print_show" style="text-indent:30px;">
#                                 人民幣 (CNY)
#                             </div>
# </div>
# </td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金買入">4.235</td>
# <td class="rate-content-cash text-right print_hide" data-table="本行現金賣出">4.397</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期買入">4.307</td>
# <td class="rate-content-sight text-right print_hide" data-hide="phone" data-table="本行即期賣出">4.357</td>
# <td class="text-center print_hide phone-small-font" data-table="遠期匯率買入/賣出"><a href="/xrt/forward/CNY">查詢</a></td>
# <td class="text-center print_hide phone-small-font" data-table="歷史匯率"><a href="/xrt/history/CNY" target="_blank">查詢</a></td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金買入">4.235</td>
# <td class="text-right display_none_print_show print_width" data-table="本行現金賣出">4.397</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期買入">4.307</td>
# <td class="text-right display_none_print_show print_width" data-table="本行即期賣出">4.357</td>
# </tr>]
